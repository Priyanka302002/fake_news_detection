# %% [markdown]
# ## import important libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import joblib
import string

# %% [markdown]
# ## load the dataset

# %%
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

# %%
# print the dataset
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %% [markdown]
# ## give class to each dataset

# %%
# 0 represet to fake news dataset
fake['class'] = 0
# 1 represent to true news dataset
true['class'] = 1

# %%
data = pd.concat([fake,true],axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 14294  THE BEST OF WATTERS’ WORLD: “If liberals are s...
# 8568    Jeb Bush Cherishes A Secret Ambition — And No...
# 12233  WATCH TUCKER CARLSON Face Off With New York Ti...
# 17677  Russia may send more Iskander missiles to Kali...
# 10432  KELLYANNE CONWAY Slaps Down Rabid CNN Host Chr...
# 14346  Zimbabwe's ruling party to launch Mugabe impea...
# 3235        U.S. senators reach deal on Russia sanctions
# 1665    Dem Lawmaker Out-Trolls Internet Troll By Cal...
# 18174  WATCH: CNN DOES SEGMENT From Bunker In Hawaii,...
# 5365   The Trump presidency on Feb. 17 at 3:49 p.m. E...
#
#                                                     text       subject  \
# 14294  Jesse Watters  is pretty awesome! He s great a...      politics
# 8568   Jeb Bush was, once upon a time in a land far, ...          News
# 12233                                                         politics
# 17677  MOSCOW (Reuters) - Russia may send more Iskand...     worldnews
# 10432  Chris Cuomo of fake news network CNN interview...      politics
# 14346  HARARE (Reuters) - Zimbabwe s ruling ZANU-PF o...     worldnews
# 3235   WASHINGTON (Reuters) - U.S. senators reached a...  politicsNews
# 1665   The Internet can be a vicious place and an ope...          News
# 18174  CNN host Erin Burnett started out her segment ...     left-news
# 5365   (Reuters) - Highlights of the day for U.S. Pre...  politicsNews
#
#                      date  class
# 14294        Mar 15, 2016      0
# 8568     January 23, 2016      0
# 12233         Dec 3, 2016      0
# 17677   October 12, 2017       1
# 10432        Jul 10, 2017      0
# 14346  November 20, 2017       1
# 3235       June 13, 2017       1
# 1665       April 27, 2017      0
# 18174        Aug 10, 2017      0
# 5365   February 17, 2017       1

# %%
data = data.drop(['title','subject','date'],axis=1)

# %%
data.sample(10)
# Out:
#                                                     text  class
# 12004  BERLIN (Reuters) - A German court sentenced a ...      1
# 21284  This story is so stupid it hurts Students at W...      0
# 20273  (Reuters) - Power outages from Hurricane Irma ...      1
# 15565  ANKARA (Reuters) - Turkey will resume processi...      1
# 18707  LONDON (Reuters) - A man accused of being part...      1
# 4614   On Thursday, Donald Trump appeared on the Dr. ...      0
# 19836  ANKARA (Reuters) - Turkish President Tayyip Er...      1
# 6907   (Reuters) - The incoming chair of the congress...      1
# 3433   As there is more and more demand by politician...      0
# 439    We always knew that Donald Trump was a heartle...      0

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis=1,inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 22046  21st Century Wire says Earlier in the week, 21...      0
# 16413  The top Democrat on the House committee invest...      0
# 20557  Two white guys living in a state where 96% of ...      0
# 41424  LONDON (Reuters) - Prime Minister Theresa May ...      1
# 34706  NORTH CHARLESTON, S.C. (Reuters) - Flaring tem...      1

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]',"",text)
    text = re.sub('\\W'," ",text)
    text = re.sub("https?:://\S+|www\.\S+","",text)
    text = re.sub("<.*?>+","",text)
    text = re.sub("[%s]" % re.escape(string.punctuation),"",text)
    text = re.sub('\n',"",text)
    text = re.sub("w*\d\w*","",text)
    return text

# %%
data['text'] = data['text'].apply(clean_text)

# %% [markdown]
# ## Select relevant features and target variable

# %%
x = data['text']
y = data['class']

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer=TfidfVectorizer()
xv_train = vectorizer.fit_transform(x_train)
xv_test=vectorizer.transform(x_test)

# %% [markdown]
# ## model selection

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
lr = LogisticRegression()
lr.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction = lr.predict(xv_test)
lr.score(xv_test,y_test)
# Out:
# 0.9861024498886414

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,'vectorizer.jb')
joblib.dump(lr,'lr_model.jb')
# Out:
# ['lr_model.jb']
